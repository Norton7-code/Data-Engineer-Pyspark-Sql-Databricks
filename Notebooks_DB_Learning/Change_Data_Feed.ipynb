# %%
# %sql
Create table sharath_lakeflow.bronze.Iris
tblproperties(delta.enableChangeDataFeed = true) 
as select * from json.`/Volumes/ingestion_catalog/inbound_ingestion_local/json_files/iris-parquet.json`;

# %%
# %sql
select * from sharath_lakeflow.bronze.Iris

# %%
# %sql
Delete from sharath_lakeflow.bronze.Iris where variety = 'Test'

# %%
# %sql
DESCRIBE HISTORY sharath_lakeflow.bronze.Iris;

# %%
# %sql
Select * from table_changes('sharath_lakeflow.bronze.Iris', 1)
