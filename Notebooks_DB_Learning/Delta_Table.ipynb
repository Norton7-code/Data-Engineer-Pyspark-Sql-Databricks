# %%
# %sql
Create table sharath_dlt.dlt_schema.hospitals
using csv location 's3://amzndeltalake/hospital.csv'

# %%
# %sql
select * from sharath_dlt.dlt_schema.hospitals;

# %%
# %sql
describe extended sharath_dlt.dlt_schema.hospitals;

# %%
df = spark.read.format("csv").options(header='true', inferSchema='true').load("s3://amzndeltalake/hospital.csv")

# %%
df.display()

# %%
df.write.format("delta").mode("overwrite").save("s3://amzndeltalake/checkpoint")

# %% [markdown]
# ##DLT framework(ETL)

# %%
# %sql
drop table ingestion_catalog.streaming_dlt.hotel

# %%
schema = """id string,
    name string,
    checkin_date date,
    checkout_date date,
    room_tye string,
    room_cost double"""
df = spark.read.format("csv").schema(schema).load("/Volumes/ingestion_catalog/streaming_dlt/streaming_sources/hotel_data.csv")
df.write.format("delta").mode("append").saveAsTable("ingestion_catalog.streaming_dlt.hotel")

# %%
# %sql
select * from ingestion_catalog.streaming_dlt.hotel;

# %%
df = spark.read.format("csv").options(header='true', inferSchema='true').load("s3://amzndeltalake/train.csv")
df.display()

# %%
df.write.format("delta").mode("append").saveAsTable("ingestion_catalog.streaming_dlt.trains")

# %%
schema = """id string,
    timestamp_ordered timestamp,
    order_id string,status string"""
df = spark.read.format("csv").schema(schema).load("s3://amzndeltalake/orders_sample1.csv")
df.display()

# %%
df.write.format("delta").mode("append").saveAsTable("ingestion_catalog.streaming_dlt.orders1")
