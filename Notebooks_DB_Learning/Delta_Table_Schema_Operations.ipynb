# %% [markdown]
# ## explicit Schema updates/operations

# %%
# %sql
DESCRIBE TABLE EXTENDED sharath_lakeflow.different_tables.credit_card

# %%
# %sql
ALTER TABLE sharath_lakeflow.different_tables.credit_card add COLUMN FLAG STRING;

# %%
# %sql
DESCRIBE TABLE EXTENDED sharath_lakeflow.different_tables.credit_card;

# %% [markdown]
# ##REORG

# %%
# %sql
REORG TABLE sharath_lakeflow.different_tables.credit_card APPLY (PURGE)

# %%
# %sql
select * from sharath_lakeflow.different_tables.credit_card;
