# %% [markdown]
# ##Table utility commands

# %% [markdown]
# ### DESCRIBE EXTENDED <TABLE_NAME>
# ### DESCRIBE HISTORY <TABLE_NAME>

# %%
# %sql

DESCRIBE EXTENDED sharath_lakeflow.different_tables.orders_external;

# %%
# %sql
DESCRIBE HISTORY sharath_lakeflow.different_tables.credit_card;

# %% [markdown]
# ####restore table to version as of <version_num>
# ####restore table timestamp as of <timestamp>

# %%
# %sql
RESTORE TABLE sharath_lakeflow.different_tables.credit_card VERSION AS OF 1;

# %% [markdown]
# ###### SHOW TBLPROPERTIES Table_Name
# ###### VACCUM location- removes files older than 7 days by default
