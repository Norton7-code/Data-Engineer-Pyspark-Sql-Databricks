# %%
import dlt
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
dlt.create_streaming_table(name = "Silver_Orders")

# %%
@dlt.append_flow(
    target = "Silver_Orders"
)
def orders_bronze1():
  df = spark.readStream.table("ingestion_catalog.streaming_dlt.orders")
  return df

# %%
@dlt.append_flow(
    target = "Silver_Orders"
)
def orders_bronze():
 df = spark.readStream.table("ingestion_catalog.streaming_dlt.orders1")
 return df

# %%
@dlt.table(
    name = "gold_orders"
)
def gold_orders():
    df = dlt.readStream("Silver_Orders")
    return df
